# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Store Open Beer Database JSON into a DataFrame

# %%
json_file = "Resources/open-beer-database.json"
openbeer_df_original = pd.read_json(json_file)
openbeer_df_original.head()
# Out:
#                       datasetid  \
# 0  open-beer-database@public-us
# 1  open-beer-database@public-us
# 2  open-beer-database@public-us
# 3  open-beer-database@public-us
# 4  open-beer-database@public-us
#
#                                               fields  \
# 0  {'website': 'http://www.michiganbrewing.com/',...
# 1  {'website': 'http://www.bigbuck.com/gaylord.ht...
# 2  {'brewery_id': '879', 'city': 'Billings', 'nam...
# 3  {'brewery_id': '901', 'city': 'Papillion', 'na...
# 4  {'brewery_id': '122', 'city': 'Missoula', 'nam...
#
#                                             geometry  \
# 0  {'type': 'Point', 'coordinates': [-84.1946, 42...
# 1  {'type': 'Point', 'coordinates': [-84.6826, 45...
# 2  {'type': 'Point', 'coordinates': [-108.506, 45...
# 3  {'type': 'Point', 'coordinates': [-96.0307, 41...
# 4  {'type': 'Point', 'coordinates': [-114.073, 46...
#
#                 record_timestamp                                  recordid
# 0  2016-09-25T21:21:38.074-07:00  76ea1712b537ab0cf0cacb8265fbed3fc422fe46
# 1  2016-09-25T21:21:38.074-07:00  d63c8dcbf0e96f79a5b6b16b92e882dbe86db3a0
# 2  2016-09-25T21:21:38.074-07:00  4e879b5db763b7e22c2029adaac8d886e8491bbe
# 3  2016-09-25T21:21:38.074-07:00  8731c6772b7401a87aad6ce9f48f8ad607158f89
# 4  2016-09-25T21:21:38.074-07:00  62a2774a7562163d8d4ab0db6640d9fc8ae4dad2

# %% [markdown]
# ### Clean Open-Beer_Database DataFrame

# %%
#split column
new_openbeer_df_original = openbeer_df_original[["fields"]]
new_openbeer_df = pd.DataFrame(new_openbeer_df_original['fields'].values.tolist())

# %%
new_openbeer_df.columns
# Out:
# Index(['abv', 'add_user', 'address1', 'brewery_id', 'cat_id', 'cat_name',
#        'city', 'coordinates', 'country', 'descript', 'filepath', 'ibu', 'id',
#        'last_mod', 'name', 'name_breweries', 'srm', 'state', 'style_id',
#        'style_name', 'upc', 'website'],
#       dtype='object')

# %%
#clean unnecessary column
openbeer_df = new_openbeer_df[["id","name","abv","cat_id","cat_name","style_id",
                               "style_name","brewery_id","name_breweries","city",
                               "state","country","coordinates"]]
openbeer_df.head()
# Out:
#      id             name  abv cat_id                cat_name style_id  \
# 0  4813  Celis Raspberry  3.9      5  Belgian and French Ale       72
# 1  4864       Buck Naked  3.2      8    North American Lager       96
# 2    93  Fat Belly Amber  0.0      3      North American Ale       33
# 3    98      Belgian Wit  0.0     -1                     NaN       -1
# 4   172      Crystal Ale  0.0     -1                     NaN       -1
#
#                      style_name brewery_id            name_breweries  \
# 0      Other Belgian-Style Ales        853          Michigan Brewing
# 1    American-Style Light Lager        114          Big Buck Brewery
# 2  American-Style Amber/Red Ale        879           Montana Brewing
# 3                           NaN        901  Nebraska Brewing Company
# 4                           NaN        122           Big Sky Brewing
#
#           city     state        country          coordinates
# 0  Webberville  Michigan  United States  [42.6616, -84.1946]
# 1      Gaylord  Michigan  United States  [45.0223, -84.6826]
# 2     Billings   Montana  United States  [45.7822, -108.506]
# 3    Papillion  Nebraska  United States  [41.1339, -96.0307]
# 4     Missoula   Montana  United States  [46.9223, -114.073]

# %%
#drop repeat id 
openbeer_df.drop_duplicates(subset ="id", keep = False, inplace = True) 
# drop rows if id is not a number
ob_df=openbeer_df[openbeer_df['id'].apply(lambda x: str(x).isdigit())].reset_index(drop=True)
ob_df.head()
# Out:
#      id                name   abv cat_id                cat_name style_id  \
# 0  4813     Celis Raspberry   3.9      5  Belgian and French Ale       72
# 1  4864          Buck Naked   3.2      8    North American Lager       96
# 2    93     Fat Belly Amber   0.0      3      North American Ale       33
# 3   172         Crystal Ale   0.0     -1                     NaN       -1
# 4   477  Criminally Bad Elf  10.5     -1                     NaN       -1
#
#                      style_name brewery_id    name_breweries         city  \
# 0      Other Belgian-Style Ales        853  Michigan Brewing  Webberville
# 1    American-Style Light Lager        114  Big Buck Brewery      Gaylord
# 2  American-Style Amber/Red Ale        879   Montana Brewing     Billings
# 3                           NaN        122   Big Sky Brewing     Missoula
# 4                           NaN       1056  Ridgeway Brewing  South Stoke
#
#       state         country          coordinates
# 0  Michigan   United States  [42.6616, -84.1946]
# 1  Michigan   United States  [45.0223, -84.6826]
# 2   Montana   United States  [45.7822, -108.506]
# 3   Montana   United States  [46.9223, -114.073]
# 4    Oxford  United Kingdom   [51.5462, -1.1355]

# %%
# select beer made in US only
ob_us_df=ob_df[ob_df["country"]=="United States"]
ob_us_df.head()
# Out:
#      id             name  abv cat_id                cat_name style_id  \
# 0  4813  Celis Raspberry  3.9      5  Belgian and French Ale       72
# 1  4864       Buck Naked  3.2      8    North American Lager       96
# 2    93  Fat Belly Amber  0.0      3      North American Ale       33
# 3   172      Crystal Ale  0.0     -1                     NaN       -1
# 5   655            Bobby  0.0     -1                     NaN       -1
#
#                      style_name brewery_id    name_breweries          city  \
# 0      Other Belgian-Style Ales        853  Michigan Brewing   Webberville
# 1    American-Style Light Lager        114  Big Buck Brewery       Gaylord
# 2  American-Style Amber/Red Ale        879   Montana Brewing      Billings
# 3                           NaN        122   Big Sky Brewing      Missoula
# 5                           NaN        935     Odell Brewing  Fort Collins
#
#       state        country          coordinates
# 0  Michigan  United States  [42.6616, -84.1946]
# 1  Michigan  United States  [45.0223, -84.6826]
# 2   Montana  United States  [45.7822, -108.506]
# 3   Montana  United States  [46.9223, -114.073]
# 5  Colorado  United States  [40.5894, -105.063]

# %%
ob_us_df["name"].value_counts()
# Out:
# Pale Ale                      44
# Porter                        26
# India Pale Ale                23
# Oktoberfest                   23
# Hefeweizen                    23
# Stout                         21
# Oatmeal Stout                 20
# IPA                           20
# Pilsner                       18
# Amber Ale                     18
# Amber                         17
# Nut Brown Ale                 14
# ESB                           13
# Imperial Stout                12
# Wheat                          9
# Red Ale                        8
# Christmas Ale                  8
# Red                            7
# Barleywine                     7
# KÃ¶lsch                        7
# Maibock                        7
# Nut Brown                      7
# Bock                           6
# Irish Stout                    6
# Weizen                         6
# Lager                          6
# Brown Ale                      6
# Scottish Ale                   6
# Grand Cru                      5
# Irish Red                      5
#                               ..
# Golden Wheat Light             1
# Red Sky Amber Lager            1
# Willow Wheat                   1
# Old Foghorn 2006               1
# Talon                          1
# Cascazilla                     1
# Artisan Saison                 1
# Dry Heat Hefeweizen            1
# Cocoa Porter                   1
# Not Tonight Honey Porter       1
# Old 55 Pale Ale                1
# Nutty Brewnette                1
# Double Paw                     1
# Rye Squared                    1
# Batch 666                      1
# Celebration Ale 1992           1
# Old English Ale                1
# Baltic Thunder                 1
# Stud Service Stout             1
# Double Crooked Tree I.P.A.     1
# Michelob Honey Lager           1
# Mocha Joe                      1
# Two-Hearted Ale                1
# Saison Rue                     1
# Kellerbier                     1
# 32 Inning Ale                  1
# White Horse Hefeweizen         1
# Long Trail Ale                 1
# Winter Cheer                   1
# Squirrel's Nut Brown           1
# Name: name, Length: 3885, dtype: int64

# %% [markdown]
# ### Store Beers CSV into DataFrame

# %%
csv_file = "Resources/beers.csv"
beers_df = pd.read_csv(csv_file)
beers_df.head()
# Out:
#        id                                  name  brewery_id state country  \
# 0  202522                        Olde Cogitator        2199    CA      US
# 1   82352  Konrads Stout Russian Imperial Stout       18604   NaN      NO
# 2  214879                        Scottish Right       44306    IN      US
# 3  320009               MegaMeow Imperial Stout        4378    WA      US
# 4  246438                       Peaches-N-Cream       44617    PA      US
#
#                      style availability   abv                   notes retired
# 0    English Oatmeal Stout     Rotating   7.3  No notes at this time.       f
# 1   Russian Imperial Stout     Rotating  10.4  No notes at this time.       f
# 2             Scottish Ale   Year-round   4.0  No notes at this time.       t
# 3  American Imperial Stout       Winter   8.7    Every time this year       f
# 4       American Cream Ale     Rotating   5.1  No notes at this time.       f

# %% [markdown]
# ### Clean Data

# %%
new_beers_df = beers_df[["id","name","brewery_id","state","country","style"]].copy()
#drop repeat id
new_beers_df.drop_duplicates(subset ="id", keep = False, inplace = True) 
#select US beer only
new_beers_us_df=new_beers_df[new_beers_df["country"]=="US"]
new_beers_us_df.head()
new_beers_us_df["name"].value_counts()
# Out:
# Oktoberfest                                        705
# IPA                                                437
# Hefeweizen                                         414
# Pale Ale                                           402
# Oatmeal Stout                                      389
# Saison                                             274
# Porter                                             265
# Imperial Stout                                     220
# ESB                                                219
# Maibock                                            210
# Double IPA                                         204
# Brown Ale                                          203
# Pumpkin Ale                                        195
# Amber Ale                                          194
# Pilsner                                            193
# Black IPA                                          190
# Kolsch                                             188
# India Pale Ale                                     183
# Cream Ale                                          161
# Vienna Lager                                       159
# Stout                                              151
# Dunkelweizen                                       148
# Baltic Porter                                      138
# Session IPA                                        131
# Irish Red                                          131
# Berliner Weisse                                    130
# Schwarzbier                                        130
# Milk Stout                                         128
# Scotch Ale                                         127
# American Pale Ale                                  127
#                                                   ...
# Custer Kölsch                                        1
# Batch 1,500                                          1
# Cucumber Blessings                                   1
# Passion of the Heights                               1
# Fire Storm's                                         1
# F-22 Raptor Double IPA                               1
# Transatlantic IPA                                    1
# Sweetwater Crank Tank Lager                          1
# Old Venerable Double Wheat                           1
# Dusselforf Brown                                     1
# U.J.P.                                               1
# Carriage Barn Series: Harvest Brown                  1
# ESB (Extra Sexy Brewer)                              1
# Prairie Limo Tint                                    1
# Ein Stein                                            1
# 5 Roses: A Rick Astley Joint (Schwartz Edition)      1
# HopCat Ignorant Pompus Arse                          1
# Apricot Vieille                                      1
# Punky                                                1
# Cointelpro                                           1
# Peachy Keen Cream Ale                                1
# Watermelon Florida Weisse                            1
# Firestone Private Label Amber Ale                    1
# Magic Bear                                           1
# Douchebag Jimmy                                      1
# The One Percenter                                    1
# The Defender American Stout                          1
# Oolong Duck Dong                                     1
# Hootenanny Harvest                                   1
# Kabuki                                               1
# Name: name, Length: 220705, dtype: int64

# %% [markdown]
# ### Store Breweries CSV into DataFrame

# %%
csv_file = "Resources/breweries.csv"
breweries_df = pd.read_csv(csv_file)
breweries_df.head()
# Out:
#       id                                  name            city state country  \
# 0  19730                       Brouwerij Danny       Erpe-Mere   NaN      BE
# 1  32541           Coachella Valley Brewing Co  Thousand Palms    CA      US
# 2  44736                      Beef 'O' Brady's      Plant City    FL      US
# 3  23372                Broadway Wine Merchant   Oklahoma City    OK      US
# 4  35328  Brighton Beer Dispensary (DUPLICATE)        Brighton   GB2      GB
#
#                                                notes                     types
# 0                             No notes at this time.                   Brewery
# 1                             No notes at this time.  Brewery, Bar, Beer-to-go
# 2                             No notes at this time.               Bar, Eatery
# 3                             No notes at this time.                     Store
# 4  Duplicate of https://www.beeradvocate.com/beer...               Bar, Eatery

# %% [markdown]
# ### Clean data

# %%
new_breweries_df =breweries_df[["id","name","city","state","country","types"]].copy()
#select US beer only
new_breweries_us_df=new_breweries_df[new_breweries_df["country"]=="US"]
new_breweries_us_df.
# Out:
#           id                             name             city state country  \
# 1      32541      Coachella Valley Brewing Co   Thousand Palms    CA      US
# 2      44736                 Beef 'O' Brady's       Plant City    FL      US
# 3      23372           Broadway Wine Merchant    Oklahoma City    OK      US
# 5      31561                   Teddy's Tavern          Seattle    WA      US
# 9      41278                    The Other End           Destin    FL      US
# 10     31711                 Ten Bells Tavern           Dallas    TX      US
# 11     12324   Bistro Europa / House Of Klaus       Alexandria    VA      US
# 14     45715  Angie's State Line Liquor Store          Enfield    CT      US
# 17     47633                  Redneck Gourmet           Newnan    GA      US
# 18     31986   Power Marketing / Wicked Pissa         Westport    MA      US
# 19     47464           Mahoney's Pub & Grille          Chicago    IL      US
# 20      8590          Wet Planet Beverage Co.            Utica    NY      US
# 23     53919    Amity Ales Brewpub and Eatery       Amityville    NY      US
# 24     17834                  The Crêpe Place       Santa Cruz    CA      US
# 25     17675                  McCray's Tavern           Smyrna    GA      US
# 26     28200                     Express Stop    Bowling Green    OH      US
# 27     48475           Springdale Barrel Room       Framingham    MA      US
# 28     43654               Modist Brewing Co.      Minneapolis    MN      US
# 31     48996           The Wandering Tortoise          Phoenix    AZ      US
# 32     26506                   The Laser Wolf  Fort Lauderdale    FL      US
# 33     18640                      The Kitchen          Boulder    CO      US
# 34     18577      The Office Beer Bar & Grill         Cranford    NJ      US
# 36     44530                        Stop Time         Brooklyn    NY      US
# 38     30224            Momma Goldberg's Deli      Baton Rouge    LA      US
# 39     40960        Ferguson's Bottles & Taps         Whitsett    NC      US
# 40     50893              Wedge at Foundation        Asheville    NC      US
# 42     41466              8one8 Brewing (818)      Canoga Park    CA      US
# 43     19754                  Brew Urban Cafe  Fort Lauderdale    FL      US
# 44     16931                     Timor Bodega       Washington    DC      US
# 45     24037                       House Wine      Worthington    OH      US
# ...      ...                              ...              ...   ...     ...
# 50306   1015   Red Car Brewery and Restaurant         Torrance    CA      US
# 50307  36480             Crystal Lake Brewing     Crystal Lake    IL      US
# 50308  29208                      The TapRoom        San Diego    CA      US
# 50309  28074                     Caps & Corks         Portland    OR      US
# 50311  17820                          The Pub   Pembroke Pines    FL      US
# 50312  15574          Festival Wine & Spirits          Oshkosh    WI      US
# 50314  13222   Trader Joe's - Brookline (501)        Brookline    MA      US
# 50315  15872               Bamber's Superette       South Bend    IN      US
# 50316  11150             Florida Brewery, Inc      Auburnville    FL      US
# 50317  20831             Aces & Ales - Nellis        Las Vegas    NV      US
# 50319  37132                      Brigantessa     Philadelphia    PA      US
# 50320  33458                        Angry Dog           Dallas    TX      US
# 50322   1665                Old Baldy Brewery           Upland    CA      US
# 50323  20114               Original Fat Cat's  Fort Lauderdale    FL      US
# 50324  22763                       Good-Ta-Go     Chambersburg    PA      US
# 50325  22154                         Bertha's        Baltimore    MD      US
# 50326  40915         Party Stop - 33rd & Bell         Amarillo    TX      US
# 50327  41031                  Mumford Brewing      Los Angeles    CA      US
# 50328  31170              Eventide Oyster Co.         Portland    ME      US
# 50330  20338                    Harris Teeter     Kernersville    NC      US
# 50331  47771         Baker Street Pub & Grill           Austin    TX      US
# 50332  39254    Pete's Olde Towne Bar & Grill   New Cumberland    PA      US
# 50333  39433            Bog Water Brewing Co.         Westport    WA      US
# 50335  39908              Old Town Pub & Grub         Temecula    CA      US
# 50336    931          Pacific Rim Brewing Co.          Seattle    WA      US
# 50338   3124      Abington Ale House & Grille         Abington    MA      US
# 50339  30980               Zipline Brewing Co          Lincoln    NE      US
# 50341  24375                The Copper Kettle         Soldotna    AK      US
# 50345  20047      Forest City Wines & Spirits       Middletown    CT      US
# 50346  13986            Landmark Beer Company         Syracuse    NY      US
#
#                           types
# 1      Brewery, Bar, Beer-to-go
# 2                   Bar, Eatery
# 3                         Store
# 5               Bar, Beer-to-go
# 9                   Bar, Eatery
# 10                  Bar, Eatery
# 11                          Bar
# 14                        Store
# 17                  Bar, Eatery
# 18                      Brewery
# 19                  Bar, Eatery
# 20                      Brewery
# 23         Brewery, Bar, Eatery
# 24                  Bar, Eatery
# 25                  Bar, Eatery
# 26                        Store
# 27                 Brewery, Bar
# 28     Brewery, Bar, Beer-to-go
# 31              Bar, Beer-to-go
# 32                          Bar
# 33                  Bar, Eatery
# 34                  Bar, Eatery
# 36                          Bar
# 38                       Eatery
# 39              Bar, Beer-to-go
# 40                 Brewery, Bar
# 42          Brewery, Beer-to-go
# 43                          Bar
# 44                        Store
# 45                        Store
# ...                         ...
# 50306      Brewery, Bar, Eatery
# 50307  Brewery, Bar, Beer-to-go
# 50308               Bar, Eatery
# 50309   Bar, Eatery, Beer-to-go
# 50311               Bar, Eatery
# 50312                     Store
# 50314                     Store
# 50315                     Store
# 50316                   Brewery
# 50317   Bar, Eatery, Beer-to-go
# 50319               Bar, Eatery
# 50320               Bar, Eatery
# 50322           Brewery, Eatery
# 50323                       Bar
# 50324   Bar, Eatery, Beer-to-go
# 50325               Bar, Eatery
# 50326                     Store
# 50327  Brewery, Bar, Beer-to-go
# 50328               Bar, Eatery
# 50330                     Store
# 50331               Bar, Eatery
# 50332   Bar, Eatery, Beer-to-go
# 50333      Brewery, Bar, Eatery
# 50335               Bar, Eatery
# 50336                   Brewery
# 50338               Bar, Eatery
# 50339  Brewery, Bar, Beer-to-go
# 50341                  Homebrew
# 50345                     Store
# 50346                   Brewery
#
# [34693 rows x 6 columns]

# %% [markdown]
# ### Create new data with select columns

# %%
obname=set(ob_us_df["name"])
beer_name=set(new_beers_us_df["name"])

# %%
#obname.intersection(beer_name)

# %%
ob_us_df_select=pd.merge(ob_us_df,new_beers_us_df, on="id", how="outer")
#ob_us_df_select = ob_us_df_select.drop_duplicates(subset="name",keep="first")
#ob_us_df_select = ob_us_df_select[["name"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-237-097de613250d> in <module>
# ----> 1 ob_us_df_select=pd.merge(ob_us_df,new_beers_us_df, on="id", how="outer")
#       2 #ob_us_df_select = ob_us_df_select.drop_duplicates(subset="name",keep="first")
#       3 #ob_us_df_select = ob_us_df_select[["name"]]
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     531         # validate the merge keys dtypes. We may need to coerce
#     532         # to avoid incompat dtypes
# --> 533         self._maybe_coerce_merge_keys()
#     534
#     535         # If argument passed to validate,
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#     978                       (inferred_right in string_types and
#     979                        inferred_left not in string_types)):
# --> 980                     raise ValueError(msg)
#     981
#     982             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
ob_us_df_select
# Out:
#         id_x                                             name  abv cat_id  \
# 0       4813                                  Celis Raspberry  3.9      5
# 1       4813                                  Celis Raspberry  3.9      5
# 2       4864                                       Buck Naked  3.2      8
# 3       4864                                       Buck Naked  3.2      8
# 4       4864                                       Buck Naked  3.2      8
# 5         93                                  Fat Belly Amber  0.0      3
# 6        172                                      Crystal Ale  0.0     -1
# 7        172                                      Crystal Ale  0.0     -1
# 8        655                                            Bobby  0.0     -1
# 9        655                                            Bobby  0.0     -1
# 10      1406                                         Pale Ale  0.0      3
# 11      1406                                         Pale Ale  0.0      3
# 12      1406                                         Pale Ale  0.0      3
# 13      1406                                         Pale Ale  0.0      3
# 14      1406                                         Pale Ale  0.0      3
# 15      1406                                         Pale Ale  0.0      3
# 16      1406                                         Pale Ale  0.0      3
# 17      1406                                         Pale Ale  0.0      3
# 18      1406                                         Pale Ale  0.0      3
# 19      1406                                         Pale Ale  0.0      3
# 20      1406                                         Pale Ale  0.0      3
# 21      1406                                         Pale Ale  0.0      3
# 22      1406                                         Pale Ale  0.0      3
# 23      1406                                         Pale Ale  0.0      3
# 24      1406                                         Pale Ale  0.0      3
# 25      1406                                         Pale Ale  0.0      3
# 26      1406                                         Pale Ale  0.0      3
# 27      1406                                         Pale Ale  0.0      3
# 28      1406                                         Pale Ale  0.0      3
# 29      1406                                         Pale Ale  0.0      3
# ...      ...                                              ...  ...    ...
# 370491   NaN                                       Bellodrama  NaN    NaN
# 370492   NaN  Untitled Art / Forager Brewing - Florida Weisse  NaN    NaN
# 370493   NaN                               Stout Constitution  NaN    NaN
# 370494   NaN                        Double Dry Hopped Tendril  NaN    NaN
# 370495   NaN                                A Page From Camus  NaN    NaN
# 370496   NaN                                       Duality #3  NaN    NaN
# 370497   NaN             Wake Up And Smell The Coffee (Nitro)  NaN    NaN
# 370498   NaN                                  Mounds Tiramisu  NaN    NaN
# 370499   NaN                                      Alton Bruin  NaN    NaN
# 370500   NaN                                       Kash Money  NaN    NaN
# 370501   NaN                                     Heather Wood  NaN    NaN
# 370502   NaN                                  Lupulor Calypso  NaN    NaN
# 370503   NaN                                    Scottish Mild  NaN    NaN
# 370504   NaN                            Ceraveza de Promenade  NaN    NaN
# 370505   NaN                                  Mandarin Dreams  NaN    NaN
# 370506   NaN                                  Out of hoptions  NaN    NaN
# 370507   NaN                                  Bar J Black Ale  NaN    NaN
# 370508   NaN         Kind Intentions Dry-Hopped American Mild  NaN    NaN
# 370509   NaN                                       Batch #017  NaN    NaN
# 370510   NaN                        Anniversary Baltic Porter  NaN    NaN
# 370511   NaN                                 Goldy Golden Ale  NaN    NaN
# 370512   NaN                                    Tasty Pig IPA  NaN    NaN
# 370513   NaN                            Mo’ Oats Mo’ Problems  NaN    NaN
# 370514   NaN                                        Turbid #2  NaN    NaN
# 370515   NaN                                 Miracle of Weird  NaN    NaN
# 370516   NaN                              Anti-Villain Saison  NaN    NaN
# 370517   NaN                        Old Fellowship Barleywine  NaN    NaN
# 370518   NaN                        Hop! Or My Mom Will Shoot  NaN    NaN
# 370519   NaN          Brewers Select #019 High Pressure Lager  NaN    NaN
# 370520   NaN                                      Rumble Fish  NaN    NaN
#
#                       cat_name style_id                    style_name  \
# 0       Belgian and French Ale       72      Other Belgian-Style Ales
# 1       Belgian and French Ale       72      Other Belgian-Style Ales
# 2         North American Lager       96    American-Style Light Lager
# 3         North American Lager       96    American-Style Light Lager
# 4         North American Lager       96    American-Style Light Lager
# 5           North American Ale       33  American-Style Amber/Red Ale
# 6                          NaN       -1                           NaN
# 7                          NaN       -1                           NaN
# 8                          NaN       -1                           NaN
# 9                          NaN       -1                           NaN
# 10          North American Ale       26       American-Style Pale Ale
# 11          North American Ale       26       American-Style Pale Ale
# 12          North American Ale       26       American-Style Pale Ale
# 13          North American Ale       26       American-Style Pale Ale
# 14          North American Ale       26       American-Style Pale Ale
# 15          North American Ale       26       American-Style Pale Ale
# 16          North American Ale       26       American-Style Pale Ale
# 17          North American Ale       26       American-Style Pale Ale
# 18          North American Ale       26       American-Style Pale Ale
# 19          North American Ale       26       American-Style Pale Ale
# 20          North American Ale       26       American-Style Pale Ale
# 21          North American Ale       26       American-Style Pale Ale
# 22          North American Ale       26       American-Style Pale Ale
# 23          North American Ale       26       American-Style Pale Ale
# 24          North American Ale       26       American-Style Pale Ale
# 25          North American Ale       26       American-Style Pale Ale
# 26          North American Ale       26       American-Style Pale Ale
# 27          North American Ale       26       American-Style Pale Ale
# 28          North American Ale       26       American-Style Pale Ale
# 29          North American Ale       26       American-Style Pale Ale
# ...                        ...      ...                           ...
# 370491                     NaN      NaN                           NaN
# 370492                     NaN      NaN                           NaN
# 370493                     NaN      NaN                           NaN
# 370494                     NaN      NaN                           NaN
# 370495                     NaN      NaN                           NaN
# 370496                     NaN      NaN                           NaN
# 370497                     NaN      NaN                           NaN
# 370498                     NaN      NaN                           NaN
# 370499                     NaN      NaN                           NaN
# 370500                     NaN      NaN                           NaN
# 370501                     NaN      NaN                           NaN
# 370502                     NaN      NaN                           NaN
# 370503                     NaN      NaN                           NaN
# 370504                     NaN      NaN                           NaN
# 370505                     NaN      NaN                           NaN
# 370506                     NaN      NaN                           NaN
# 370507                     NaN      NaN                           NaN
# 370508                     NaN      NaN                           NaN
# 370509                     NaN      NaN                           NaN
# 370510                     NaN      NaN                           NaN
# 370511                     NaN      NaN                           NaN
# 370512                     NaN      NaN                           NaN
# 370513                     NaN      NaN                           NaN
# 370514                     NaN      NaN                           NaN
# 370515                     NaN      NaN                           NaN
# 370516                     NaN      NaN                           NaN
# 370517                     NaN      NaN                           NaN
# 370518                     NaN      NaN                           NaN
# 370519                     NaN      NaN                           NaN
# 370520                     NaN      NaN                           NaN
#
#        brewery_id_x                name_breweries          city   state_x  \
# 0               853              Michigan Brewing   Webberville  Michigan
# 1               853              Michigan Brewing   Webberville  Michigan
# 2               114              Big Buck Brewery       Gaylord  Michigan
# 3               114              Big Buck Brewery       Gaylord  Michigan
# 4               114              Big Buck Brewery       Gaylord  Michigan
# 5               879               Montana Brewing      Billings   Montana
# 6               122               Big Sky Brewing      Missoula   Montana
# 7               122               Big Sky Brewing      Missoula   Montana
# 8               935                 Odell Brewing  Fort Collins  Colorado
# 9               935                 Odell Brewing  Fort Collins  Colorado
# 10              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 11              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 12              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 13              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 14              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 15              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 16              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 17              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 18              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 19              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 20              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 21              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 22              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 23              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 24              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 25              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 26              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 27              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 28              932  Oasis Brewery and Restaurant       Boulder  Colorado
# 29              932  Oasis Brewery and Restaurant       Boulder  Colorado
# ...             ...                           ...           ...       ...
# 370491          NaN                           NaN           NaN       NaN
# 370492          NaN                           NaN           NaN       NaN
# 370493          NaN                           NaN           NaN       NaN
# 370494          NaN                           NaN           NaN       NaN
# 370495          NaN                           NaN           NaN       NaN
# 370496          NaN                           NaN           NaN       NaN
# 370497          NaN                           NaN           NaN       NaN
# 370498          NaN                           NaN           NaN       NaN
# 370499          NaN                           NaN           NaN       NaN
# 370500          NaN                           NaN           NaN       NaN
# 370501          NaN                           NaN           NaN       NaN
# 370502          NaN                           NaN           NaN       NaN
# 370503          NaN                           NaN           NaN       NaN
# 370504          NaN                           NaN           NaN       NaN
# 370505          NaN                           NaN           NaN       NaN
# 370506          NaN                           NaN           NaN       NaN
# 370507          NaN                           NaN           NaN       NaN
# 370508          NaN                           NaN           NaN       NaN
# 370509          NaN                           NaN           NaN       NaN
# 370510          NaN                           NaN           NaN       NaN
# 370511          NaN                           NaN           NaN       NaN
# 370512          NaN                           NaN           NaN       NaN
# 370513          NaN                           NaN           NaN       NaN
# 370514          NaN                           NaN           NaN       NaN
# 370515          NaN                           NaN           NaN       NaN
# 370516          NaN                           NaN           NaN       NaN
# 370517          NaN                           NaN           NaN       NaN
# 370518          NaN                           NaN           NaN       NaN
# 370519          NaN                           NaN           NaN       NaN
# 370520          NaN                           NaN           NaN       NaN
#
#             country_x          coordinates      id_y  brewery_id_y state_y  \
# 0       United States  [42.6616, -84.1946]   11772.0         565.0      MI
# 1       United States  [42.6616, -84.1946]  340180.0       49549.0      TX
# 2       United States  [45.0223, -84.6826]  363469.0       29278.0      PA
# 3       United States  [45.0223, -84.6826]  181740.0       29278.0      PA
# 4       United States  [45.0223, -84.6826]   61449.0        5077.0      OR
# 5       United States  [45.7822, -108.506]   20960.0         999.0      MT
# 6       United States  [46.9223, -114.073]   17699.0         751.0      MT
# 7       United States  [46.9223, -114.073]   11515.0        2104.0     NaN
# 8       United States  [40.5894, -105.063]  268461.0       45814.0      CT
# 9       United States  [40.5894, -105.063]    4335.0         267.0      CO
# 10      United States   [40.015, -105.271]  328132.0       47863.0      OH
# 11      United States   [40.015, -105.271]  280600.0       45647.0      TX
# 12      United States   [40.015, -105.271]   94503.0       26950.0      PA
# 13      United States   [40.015, -105.271]  176954.0       40217.0      TX
# 14      United States   [40.015, -105.271]    5939.0        1299.0      VA
# 15      United States   [40.015, -105.271]      87.0         147.0      CA
# 16      United States   [40.015, -105.271]   12170.0        6313.0      CA
# 17      United States   [40.015, -105.271]  207204.0         710.0      WI
# 18      United States   [40.015, -105.271]    2708.0         764.0      NY
# 19      United States   [40.015, -105.271]  329717.0       49155.0      HI
# 20      United States   [40.015, -105.271]  318004.0        3798.0      NM
# 21      United States   [40.015, -105.271]  153539.0       35182.0      ID
# 22      United States   [40.015, -105.271]    1962.0         567.0      WA
# 23      United States   [40.015, -105.271]   31446.0       14179.0      MO
# 24      United States   [40.015, -105.271]  274402.0       47673.0      NY
# 25      United States   [40.015, -105.271]  309460.0       50836.0      VA
# 26      United States   [40.015, -105.271]  299084.0       50294.0      WA
# 27      United States   [40.015, -105.271]   26420.0       11715.0      PA
# 28      United States   [40.015, -105.271]   25656.0        9020.0      TN
# 29      United States   [40.015, -105.271]   27964.0       11580.0      CA
# ...               ...                  ...       ...           ...     ...
# 370491            NaN                  NaN  231497.0       41428.0      CO
# 370492            NaN                  NaN  292515.0       47802.0      WI
# 370493            NaN                  NaN  218523.0       44028.0      NE
# 370494            NaN                  NaN  267957.0       33482.0      RI
# 370495            NaN                  NaN  154296.0       28019.0      CA
# 370496            NaN                  NaN  279735.0       32931.0      CA
# 370497            NaN                  NaN  274810.0       41170.0      NJ
# 370498            NaN                  NaN  222927.0       37910.0      VA
# 370499            NaN                  NaN  183563.0       16873.0      OR
# 370500            NaN                  NaN  268773.0       31515.0      ME
# 370501            NaN                  NaN  240765.0        1513.0      OH
# 370502            NaN                  NaN  287004.0       45869.0      IL
# 370503            NaN                  NaN  344035.0       49830.0      IL
# 370504            NaN                  NaN  356520.0       34416.0      WA
# 370505            NaN                  NaN  319005.0       50037.0      FL
# 370506            NaN                  NaN  317611.0       47738.0      FL
# 370507            NaN                  NaN  169208.0       40209.0      MN
# 370508            NaN                  NaN  225277.0       41849.0      VA
# 370509            NaN                  NaN  323146.0       38054.0      OH
# 370510            NaN                  NaN  196378.0       30492.0      NM
# 370511            NaN                  NaN  343772.0       29442.0      MN
# 370512            NaN                  NaN  339481.0       49641.0      FL
# 370513            NaN                  NaN  360048.0       36428.0      CA
# 370514            NaN                  NaN  271967.0       32908.0      FL
# 370515            NaN                  NaN  323062.0       41542.0      PA
# 370516            NaN                  NaN  279488.0       47686.0      CA
# 370517            NaN                  NaN  208152.0       41966.0      OR
# 370518            NaN                  NaN  168135.0       26850.0      KY
# 370519            NaN                  NaN  258269.0       28281.0      WA
# 370520            NaN                  NaN  283124.0       29238.0      MI
#
#        country_y                       style
# 0             US        Fruit and Field Beer
# 1             US             Belgian Witbier
# 2             US          American Cream Ale
# 3             US     American Pale Ale (APA)
# 4             US          American Brown Ale
# 5             US       English Dark Mild Ale
# 6             US               German Kölsch
# 7             US               German Kölsch
# 8             US                American IPA
# 9             US               German Kölsch
# 10            US     American Pale Ale (APA)
# 11            US     American Pale Ale (APA)
# 12            US     American Pale Ale (APA)
# 13            US     American Pale Ale (APA)
# 14            US     American Pale Ale (APA)
# 15            US     American Pale Ale (APA)
# 16            US     American Pale Ale (APA)
# 17            US     American Pale Ale (APA)
# 18            US     American Pale Ale (APA)
# 19            US     American Pale Ale (APA)
# 20            US     American Pale Ale (APA)
# 21            US     American Pale Ale (APA)
# 22            US     American Pale Ale (APA)
# 23            US     American Pale Ale (APA)
# 24            US     American Pale Ale (APA)
# 25            US     American Pale Ale (APA)
# 26            US     American Pale Ale (APA)
# 27            US     American Pale Ale (APA)
# 28            US     American Pale Ale (APA)
# 29            US            Belgian Pale Ale
# ...          ...                         ...
# 370491        US               German Kölsch
# 370492        US             Berliner Weisse
# 370493        US              American Stout
# 370494        US                American IPA
# 370495        US            Belgian Pale Ale
# 370496        US     American Pale Ale (APA)
# 370497        US              American Stout
# 370498        US     American Imperial Stout
# 370499        US     Belgian Strong Dark Ale
# 370500        US                American IPA
# 370501        US         Herb and Spice Beer
# 370502        US       American Imperial IPA
# 370503        US       English Dark Mild Ale
# 370504        US  American Amber / Red Lager
# 370505        US     American Pale Wheat Ale
# 370506        US                American IPA
# 370507        US          American Black Ale
# 370508        US       English Pale Mild Ale
# 370509        US                American IPA
# 370510        US               Baltic Porter
# 370511        US         American Blonde Ale
# 370512        US                American IPA
# 370513        US       English Oatmeal Stout
# 370514        US                American IPA
# 370515        US       American Imperial IPA
# 370516        US              Belgian Saison
# 370517        US         American Barleywine
# 370518        US                American IPA
# 370519        US              American Lager
# 370520        US       American Imperial IPA
#
# [370521 rows x 18 columns]
